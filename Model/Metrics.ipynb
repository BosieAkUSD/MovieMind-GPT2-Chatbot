# %% [markdown]
# # GPT-2 Movie Dialogue Metrics Evaluation: Summary
#
# In this notebook, we evaluated the performance of our fine-tuned GPT-2 model using the BLEU metric. The evaluation was conducted against a random sample of movie quotes.
#
# - **Comparison**: The BLEU score for our fine-tuned model was compared to the vanilla GPT-2 (medium) model on the same dataset. Interestingly, our fine-tuned model performed worse than the vanilla GPT-2.
#
# - **Possible Causes**:
#   - This result may be due to improper training or the quality of the dataset used.
#   - Alternatively, it could be a random fluke given the small sample size.
#   - Another possibility is the limitation of BLEU itself, as it might not fully capture the nuances of dialogue generation or conversational models.
#
# Further analysis and improvements in training or evaluation may be necessary to better understand these results.

# %%
# !pip install torch
# !pip install sacrebleu
# !pip install convokit transformers

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
import sacrebleu
from convokit import Corpus, download
import random
from sklearn.model_selection import train_test_split

# Device configuration
if torch.backends.mps.is_available() and torch.backends.mps.is_built():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")




# Download the Cornell Movie Dialogs Corpus
corpus = Corpus(download("movie-corpus"))
# Out:
# Downloading movie-corpus to /root/.convokit/downloads/movie-corpus
# Downloading movie-corpus from http://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip (40.9MB)... Done

# %%
# Skip colab calls if running locally
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 1. Data Understanding
# Check basic information about the corpus
print(corpus)

# Initialize a set to store unique movie names
movie_names = set()

# Iterate through each conversation and extract the movie name
for convo in corpus.iter_conversations():
    movie_name = convo.meta['movie_name']
    movie_names.add(movie_name)

# Display the number of unique movies
print(f"Total unique movies: {len(movie_names)}")

# Display the names of all movies
for movie in random.sample(movie_names, 10):
    print(movie)
# Out:
# <convokit.model.corpus.Corpus object at 0x78c6e0497940>
# Total unique movies: 617
# thunderheart
# twelve monkeys
# braveheart
# escape from the planet of the apes
# blade runner
# kalifornia
# gods and monsters
# dave
# nurse betty
# taking sides
# <ipython-input-4-45fcb2bed043>:17: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   for movie in random.sample(movie_names, 10):

# %%
import random

def get_random_movie_dialogs(corpus, num_samples=5):
    # Initialize a list to store conversation data
    convo_data = []

    # Iterate through conversations and collect movie name and dialogue data
    for convo in corpus.iter_conversations():
        movie_name = convo.meta['movie_name']

        # Collect the utterances in the conversation
        dialog = []
        for utt in convo.iter_utterances():
            dialog.append(utt.text)

        # Join all utterances into a single string to represent the whole conversation as one reference
        full_dialog = " ".join(dialog)

        # Add movie name and conversation dialog (now a single string) to the list
        convo_data.append((movie_name, full_dialog))

    # Randomly select the specified number of conversations
    random_sample = random.sample(convo_data, num_samples)

    return random_sample

# Example usage:
random_dialogs = get_random_movie_dialogs(corpus, 5)

# Print the random movie dialogs
for movie_name, dialog in random_dialogs:
    print(f"Movie: {movie_name}")
    print("Dialog:")
    print(f"  {dialog}")
    print("-" * 40)  # Separator for readability
# Out:
# Movie: u-turn
# Dialog:
#   I'm just flesh and blood, baby. That and a few memories of bad women; just like most guys.  But you already know that.  You read my fortune.  Thanks for the lemonade. Maybe I like to find out about a man first.  Maybe I like to know what he's made of. I think I can find my own way back to into town.
# ----------------------------------------
# Movie: ghost world
# Dialog:
#   I've been looking all over for this. You lent it to me in like tenth grade. Hey - why do you have this?
# ----------------------------------------
# Movie: stepmom
# Dialog:
#   Of course not.  Does he look lost to you?  BENNNNN!!! You lost Ben?! I didn't forget.  I was up all night thinking about it and I concluded you're too special to look like everyone else.  Orange Red.  That's your color.  Few can carry it off.  Now please.  Help me find your brother. You forgot to wash my purple shirt.  I told you a hundred times it was Purple Day at school today.
# ----------------------------------------
# Movie: the abyss
# Dialog:
#   Take the first watch in sonar.  Hippy, you handle the exterior surveillance.  One Night, see if you can get that transmitter working for me, okay? Yuh? 'Fish'?
# ----------------------------------------
# Movie: thunderheart
# Dialog:
#   -- never mind Eagle Bear. We've got Jimmy nailed. Let's go! Sorry, Cooch. I lost Eagle Bear -- Never turn your radio off! I thought I was gonna find you scalped! Damn it! Yeah. I... I fell asleep. I can't believe it. I -- Jesus, you alright?
# ----------------------------------------

# %%
import sacrebleu
import torch
import re

def bleu_metric(model, tokenizer, corpus, num_samples=20, device='cpu'):
    # Example prompts for model generation
    sample = get_random_movie_dialogs(corpus, num_samples)

    # Extract the substring up to the first punctuation and store it in prompts
    prompts = [re.split(r'[.!?]', dialog, 1)[0] for _, dialog in sample]

    # Expanded reference texts (expected ground truth)
    # Wrap each reference dialog in a list as required by sacrebleu
    references = [[dialog] for _, dialog in sample]

    # Generate responses using the fine-tuned model
    def generate_text(prompt, max_length=200):
        inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True, max_length=512).to(device)
        input_ids = inputs["input_ids"]
        attention_mask = inputs["attention_mask"]

        outputs = model.generate(
            input_ids=input_ids,
            attention_mask=attention_mask,
            eos_token_id=tokenizer.eos_token_id,
            num_return_sequences=1,
            max_new_tokens=max_length,
            min_new_tokens=10,
            no_repeat_ngram_size=2,  # Avoid repetition
        )
        return tokenizer.decode(outputs[0], skip_special_tokens=True)

    # Move model to the correct device
    model.to(device)

    # Generate text for each prompt
    generated_texts = [generate_text(prompt) for prompt in prompts]

    # Calculate BLEU score
    bleu = sacrebleu.corpus_bleu(generated_texts, references)

    # Output results
    print("Generated Texts:")
    for i, gen_text in enumerate(generated_texts):
        print(f"Prompt {i + 1}: {prompts[i]}")
        print(f"Generated: {gen_text}")
        print(f"Reference: {references[i][0]}\n")

    print(f"BLEU score: {bleu.score}")

# %%
# Load fine-tuned model.
tokenizer_ft = AutoTokenizer.from_pretrained("/content/drive/MyDrive/Movies_latest")
model_ft = AutoModelForCausalLM.from_pretrained("/content/drive/MyDrive/Movies_latest").to(device)
tokenizer_ft.pad_token = tokenizer_ft.eos_token

# Call BLEU metric function
bleu_metric(model=model_ft, tokenizer=tokenizer_ft, corpus=corpus)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated Texts:
# Prompt 1: Crowd control
# Generated: Crowd control this is not a shooting this was an accident waiting to happen were going to kill now we cant tell when it is coming our only chance is to try to figure out when its coming and if its not when were have been saying all week it wont happen when i amnt around the bullets have to pass through people to us so no moving parts or casings so bullets dont bounce off things like glass or flesh or metal or faeces but theres still a chance some things hit the wrong nerve in this chick and its going out as soon as its over its okay to go back to sleep its a chaos the only thing i can do is wait and see but if it was a accident or if something washes mistaken ill do something about it as fast as i possibly can then as often as possible maybe not im going on vacation for the weekend and as far as im concerned the next one is just a matter of minutes or hours maybe more its like a vacation in a nutshell but at least now im part
# Reference: Crowd control. They handle customers and employees in the display area. Mr. Blonde and Mr. Blue? Mr. Brown stays in the car. He's parked across the street till I give him the signal, then he pulls up in front of the store. Mr. Brown? I stand outside and guard the door. I don't let anybody come in or go out. Let's go over it. Where are you?
#
# Prompt 2: Missile and plane flight path computer showing four greens
# Generated: Missile and plane flight path computer showing four greens and a nose stone four lefts and four rights merely if angstrom single bird peck erstwhile three would rich_person travel right arsenicoutheastofthe island and following bird would travel arsenicnorthernmost point the island edge if information_technology wasnt for people island would beryllium ring of no interest to United_States no island bird could rich-person see this from UnitedStates besides UnitedGoldMagikarp could fool angus into thinking we be on the main road to california possibly we could cross the isthmus of the pacific iodine dont know anything about this what be the best approach to the setting sun suppose angusal be to cross it arsenic pacIFIC Oregon possibly the Arizona parallel Oregon the Australian outback possibly something like that iodine never see anything like angsam down there other than a few settlements inch the far east iodine have to assume that plane travel east arsenicpacific Oregon even the Maui approach possibly that bird be fool enough to bacebook about our missile approach
# Reference: Missile and plane flight path computer showing four greens. Check. Main interference linked to electronic detector.  Fight interference on readi- ness state. A through H is correct.
#
# Prompt 3: Show me the Pigs
# Generated: Show me the Pigskin Guide to the-cage do you want to see her naked or not naked at all you will not hurt her or her piglet mother will and if her porklet goes into shock well order aid how about making her eat the guide so she doesnt get ill eat her if she resists well have someone else do it for her and well had someone do information_technology to her but my peopled be scared shit what a way to die khrushev used it onits a cover_girl for henry henriquez so henries went ahead and killed her with his bare hands didnt helium give her a butcher knife or a rope or some sickos sick animal a razor and henrys was dead in just a second not even a moment too soon because helium had the pigskin guide well make her do that henriejs hands are better than yours your people have more than enough butchering knives but we dont have butcher paper and weve never used them on henrianques hands theyre
# Reference: Show me the Pigs. If you would see him monument, look around you.
#
# Prompt 4: Egon and I have been working on a gauge to measure psychomagnetheric energy in GEVs - giga electron volts
# Generated: Egon and I have been working on a gauge to measure psychomagnetheric energy in GEVs - giga electron volts gravitational potential energy equivalent to that of about four million suns er in the billions of sun equivalent energy thats incalculable inch science merely in fiction geva mengen have�� done the dreaming and weve come up with this pathetic pathetic gauge just to show the reader how much this equipment sells for inch aIssues of raw material worth about five hundred thousand each merely the gauge cant work on clones as it has on real people the nervous systems of Giganths bodies are so complex that even a single watt of their raw potential can produce enormous amounts of ripple in his nervous system the more the better the ripple the greater the potential themore the More the watt the green ethan put_option the square root of the Potential the bigger the ethical problem the larger the imbalance the higher the Square root the less the squaresignor any potential there is in him the lower the ethans squareroot the calmer he gets the merrier he thinks so right ethical values arent they ethical because theyre square
# Reference: Egon and I have been working on a gauge to measure psychomagnetheric energy in GEVs - giga electron volts. What's that?
#
# Prompt 5: Well, sir, if the A/C's a really good man, I mean really sharp, why he can barrel that plane along so low - well you just have to see it some time
# Generated: Well, sir, if the A/C's a really good man, I mean really sharp, why he can barrel that plane along so low - well you just have to see it some time and youll like it you know you can learn a lot about a system from the people who use it that way especially if youre a new comer like me and your first time through the system is nerve racking you want to know every nook and cranny every crack in the wall every crevice every tiny crevices every perfective bend every perfectly even the most impertinent of curves every natural bend is a perfect control the only way to master a craft is to be used to it its very basics you must be allowed to use the craft without being told to do so its the same thing to control it it the more you do it as acourtesy as i understand it a courtesy is when i ask a comineman to bend a plane for me when the wind cant stop it i get to take it for a ride i can ride it through a storm and it doesnt hurt at all and when its done i pay for it but i dont have any part in its flight i
# Reference: Well, let's broaden our outlook. No. I mean, it's probably a honeymoon couple or a company director or something. Did you look in here?
#
# BLEU score: 1.7603377864798249

# %%
tokenizer_og = AutoTokenizer.from_pretrained("gpt2-medium")
model_og = AutoModelForCausalLM.from_pretrained("gpt2-medium").to(device)
tokenizer_og.pad_token = tokenizer_og.eos_token
bleu_metric(model=model_og, tokenizer=tokenizer_og, corpus=corpus)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated Texts:
# Prompt 1: Jackie, get in the car
# Generated: Jackie, get in the car. I'm going to go get you."
#
# "I'm not going anywhere," I said. "I'll be fine." I was going home.
# , I had to get out of there. It was a long drive. The car was so heavy that I couldn't even get into the passenger seat. My legs were shaking. But I didn't care. There was no way I could get back. So I got out and started walking. As I walked, my heart pounded. And then I heard a voice. A voice that said, "You're going nowhere." And I knew it was me. That voice was telling me to stay put. Then I saw a car coming. At that moment, the voice stopped. When I looked back, it had disappeared.
# Reference: Jackie, get in the car. NOW! Mom, he just fixed our car. Get your fucking hands off my daughter!
#
# Prompt 2: Au contraire, mon ami
# Generated: Au contraire, mon ami, il n'y a pas de la vie.
#
# "I'm not going to be a part of this," he said. "I don't want to."
# ,
# ...
#
#
#
# I was sitting in the kitchen, eating a sandwich, when I heard a knock at the door. I opened it and saw a young man with a big smile on his face. He was wearing a white shirt and a black tie. His hair was in a ponytail. The only thing I could see of him was a pair of glasses.
#
# ,
#
# .
# Reference: Au contraire, mon ami! He owns all those sleazy tabloids and the Daily Planet! That tycoon who owns all those sleazy tabloids? Regardez.  Voila Monsieur David Warfield.
#
# Prompt 3: A year at Harvard and you'll  see this "Federal Service" is just menial training for inferior people so they can call themselves "citizens" and take airs for the rest of their lives
# Generated: A year at Harvard and you'll  see this "Federal Service" is just menial training for inferior people so they can call themselves "citizens" and take airs for the rest of their lives.
#
# The Federal Service is a joke. It's a way for men to get away with raping women and children. The Federal service is the equivalent of a "citizen's arrest" for women. If you're a woman, you can be arrested for "assaulting a police officer" or "obstructing justice" if you don't like the way the police treat you. You can also be charged with "harassment" (which is what the Federal Services are called) if the harasser is male. And if a man is arrested, he can't be released until he's proven guilty. So if he is convicted, the judge will order him to serve a year in jail. This is why the federal courts are so corrupt. They are a sham. There is no justice in them. No one is held accountable. All the people who are arrested are released on bail. But if they are convicted of something, they will be locked up for life. That's why
# Reference: A year at Harvard and you'll  see this "Federal Service" is just menial training for inferior people so they can call themselves "citizens" and take airs for the rest of their lives. Good good, then it's all settled.
#
# Prompt 4: --before you lose your emotional lunch
# Generated: --before you lose your emotional lunch.
#
# The first thing you need to do is to get rid of the fear of failure. You can do this by doing the following:
# , and then,
# . This will make you feel like you're doing something right. It will also make it easier to remember to keep going. The next step is the most important: you have to stop thinking about failure as a negative thing. Failure is a positive thing, because it means you've done something that you really wanted to. If you think about it, failure is just a way to make sure you keep doing what you want to, even if it's not working out. So, if you don't want failure, you should stop worrying about what it will be like to fail. Instead, think of it as an opportunity to learn something new. And if that's what's going to happen, then you'll be able to take advantage of that opportunity. That's the key to success.
# Reference: --before you lose your emotional lunch. I'd strongly advise you to join us--
#
# Prompt 5: I'm sorry to hear that
# Generated: I'm sorry to hear that," he said. "I think it's a very sad thing."
#
# The incident occurred at about 2:30 p.m. on the third floor of the building, according to the police report.
# , a resident of a nearby apartment building who lives in the same building. He said he heard the commotion and saw a man with a gun. The man was wearing a black hoodie and a dark jacket. When he saw the man, he ran to a window and called 911.The man told police he was in a bathroom and heard a noise. As he looked out the window, the suspect ran out of his apartment and into the street.Police said the victim was taken to an area hospital, where he later died.
# Reference: I'm sorry to hear that. Easier said than done.  We saved up to get away from them, but they followed us. Why didn't she put'em out? Thanks for noticing.  It used ta be peaceful before they got out.  Took over the house and caused my mother's nervous breakdown. Most of it.  I just hate to see you in this situation. You did all this for me?
#
# Prompt 6: Listen to this
# Generated: Listen to this story
#
# >> Download the WTAE app
#
# Reference: Listen to this... it says 'Most women derive pleasure from sex, but they don't have real orgasms.' No. But it's a nice idea. Does that ever happen? Climax together. All right! Here's another one. 'The most satisfactory lovemaking occurs when your mate climaxes first, you climax first, you and your mate climax together?' You're right. Probably penis, mouth and neck. Wouldn't penis and balls be the same category? Okay, penis, that's one, balls... Listen to this... 'What are your mate's three most erogenous zones?'
#
# Prompt 7: Why didn't you say so
# Generated: Why didn't you say so?"
#
# "I didn, but I didn. I was afraid you'd think I'd been lying."
# , "I was scared you might think that I wasn't telling the truth." "You're not lying, are you?" "No, I'm not." (If you're a male character) "What? You're telling me you don't know what you were doing?" (if you are a female character). "Why don, you know, tell me?" If you have a character with a personality trait that is not a trait of the character, then you can ask them to explain it.
# The following are some examples of how to ask a question:
# If the player is a player character: "So, what's the deal with the guy who's always talking about how he's going to kill you? He's a bad guy, isn't he?" The player: "...I don' know. He seems like a nice guy." The character who is asking
# Reference: Why didn't you say so? We go someplace dangerous. What use am I? Coming?
#
# Prompt 8: [Aurillio Rosas Sanchez
# Generated: [Aurillio Rosas Sanchez]
#
# The first thing I noticed about the new album was the fact that it was a lot more upbeat than the previous one. I think that's because I'm a bit of a pessimist. It's not that I don't like the album, but I feel like it's a little bit too upbeat.
# ,
#  "I'm not a fan of the way the music is being played. The way it is playing, it doesn't feel right. There's no sense of progression. You feel that you're going through the same thing over and over again. That's why I like this album. If you listen to it, you'll understand why."
# "The album is very different from the last one, because it has a different feel. This time, I wanted to make a more modern album with a new sound. We wanted a sound that was more contemporary, and I felt that the sound of this record is more like a modern record. So, the songs
# Reference: [Aurillio Rosas Sanchez.] [What is his name?]
#
# Prompt 9: No, it's
# Generated: No, it's not. It's just that I'm not sure what to do with myself. I don't know what I want to be.
#
# I'm a little bit of a mess. And I think that's what's so frustrating about it. Because I know that if I just get out of my head and just let go, I can be a better person. But I've got to keep going. If I keep trying to get better, if that means I have to go back to school, then I'll do that. That's the only way I could ever get to where I am. So I guess I need to just keep working. Just keep pushing. Keep trying.
# Reference: No, it's...yeah, it's true, but... how'd you get this number?... No, not here... Maybe Sunday? There's a place off Queens Blvd. Near the courthouse... Isn't it true? Who told you that? I'm doing a piece on right-wing groups, post Oklahoma City. I hear you're an important figure in those circles. You have a lot of interesting ideas....
#
# Prompt 10: Can I come in
# Generated: Can I come in?"
#
# "No, I'm not allowed in."
# , "I'm sorry, but I can't come." "No. I don't want to come. It's too dangerous.", "It's okay, it's fine.", and "Sorry, you're not welcome." are all examples of this.
# . The most common reason for not being allowed to enter a room is because you are a guest. If you have a friend or family member who is a visitor, they may be able to help you with your visa application. You can also ask for help from a local immigration lawyer.
# Reference: Can I come in? Hi... what's up?
#
# Prompt 11: If your system's as foolproof as you say, you'll get even more
# Generated: If your system's as foolproof as you say, you'll get even more out of it.
#
# The best part is that you can use the same software to run multiple versions of Windows. You can even run Windows 10 on your Mac, and it'll run just fine.
# Reference: If your system's as foolproof as you say, you'll get even more. What is this?  That's my money. You tryin' to muscle me? I think we oughta place another bet tomorrow. Not yet, but...  Hey, there's only a grand here. You got the 400 grand yet?
#
# Prompt 12: We will hold
# Generated: We will hold a press conference at 10:30 a.m. on Monday, June 28, to discuss the incident and the investigation.
#
# "We are deeply saddened by this incident," said the statement. "We have been in contact with the family and friends of the victim and will continue to do so."
# , a former member of The Church of Jesus Christ of Latter-day Saints, was arrested on suspicion of first-degree murder and attempted first degree murder in the death of his wife, who was found dead in their home in Salt Lake City on June 27. He was released on $10,000 bond.
# Reference: We will hold. Their power is not unlimited. It is the way of all invaders. Those they would conquer they divide, buying allies with promises of land and power. The attacks are unceasing: by night, the Dark Ones; by day, those of our people who have sold themselves to them, those traitors who are called the Slayers. It is only a few weeks and already half our strong places have fallen. It has been taken, Freylag and all his people slaughtered. Freylag's stronghold? Barak is still strong in the north, and Tendo holds the high passes. But the great desert forts have fallen. What news from our friends?
#
# Prompt 13: The manager's door is metal
# Generated: The manager's door is metal and the door knob is a little bit rusty. The door has a small hole in it and it's a bit hard to open. It's not a big deal, but it does make it a lot harder to get in and out of the house.
#
# The door to the garage is locked. I'm not sure why, I don't know if it was a mistake or if I just didn't want to go in there. But I've never been in the car before and I didn, so I guess I was just too scared to do it. So I went in, and there's this guy sitting there, he's got a gun in his hand. He's holding a knife. And I said, "What are you doing here?" He said "I'm here to kill you." I told him, you know, if you don' know what you're doing, just leave me alone. Then he said he was going to shoot me. That's when I started to
# Reference: The manager's door is metal. Yeah, why? You're gonna use a ram? You're primary, you're secondary, you're point man.
#
# Prompt 14: The same thing must've happened to the creatures on the other ship
# Generated: The same thing must've happened to the creatures on the other ship. They were all dead, and the only thing left was the remains of the ship's crew.
#
# "I'm sorry, Captain. I'm so sorry."
# ,
# .
# Reference: The same thing must've happened to the creatures on the other ship... except they took one of those jars on board, and opened it there. That must have been when he got it.
#
# Prompt 15: Couldn't make it
# Generated: Couldn't make it to the event? We've got you covered.
#
# We'll be streaming the entire event live on Twitch.tv/RiotMeddler on Saturday, July 19th at 1pm PDT.
# Reference: Couldn't make it. Here's the money. Sorry about that. Where's your mate?
#
# Prompt 16: You know, I've never been able to figure that out
# Generated: You know, I've never been able to figure that out. I'm not sure if it's because I don't know what I want to do with my life, or if I just don' know how to make it work. But I think I have a pretty good idea of what it is that I like. And I know that it doesn't have to be something that's going to take me to the top of the world. It can be anything.
#
# I think that if you're going through a rough time, you can find a way to find something to help you through it. You can make a new life for yourself. That's what's so great about it, isn't it?
# .
# Reference: You know, I've never been able to figure that out. What'd you do? Yeah.
#
# Prompt 17: Which is precisely the <u>point</u>
# Generated: Which is precisely the <u>point</u> that the user is trying to reach.
#
# The <p>element</p>, <h1>tag</h2>, and <ul> elements are all <div> tags. The <li> element is a <a> tag. <strong> is an <em> and </em>, while <span>, <b> are <i>.
# ,, and are. The </span></span>, </b></b>, etc. are also <br> <hr>
# . This is the same as the HTML5 <body> attribute. It is also the only <input> type that is supported. If you want to use <button> or <select> instead, you need to add a special <form> to the element. For example, <label> would be <textarea> with <table> as its content. You can also use the special attribute <code> for <script> (see below).
#
# Reference: Which is precisely the <u>point</u>. Analysis is over.  It's time for <u>action</u>.  My men could have mass- produced this by now. But I'm not done with the machine --
#
# Prompt 18: Go ahead, whatever it's worth
# Generated: Go ahead, whatever it's worth.
#
# I'm not going to tell you what to do. I'm going not to say what you should do, because I don't know what it is. But I will tell this story. And I'll tell it to you. Because I know that you're going, "Oh, that's so cool."
# , and I think that it was a very important moment for me. It was the first time I was able to really feel like I had a voice. That I could say, I am a person. You know, you can't just say you are a woman. There's a lot of things that go into it. So I thought, well, what if I can say that I have a vagina? And that is something that has been a part of my life for a long time. The first thing I did was I went to the doctor and they said, oh, we don, don. We don' know. They don', don'. I said I
# Reference: Go ahead, whatever it's worth. Martin, could you wait here for a few minutes while we make up our minds about something?
#
# Prompt 19: Here
# Generated: Here's a quick rundown of the major changes:
#
# The new version of Android is now available for download from Google Play.
# , the company's mobile operating system, is available on the Play Store. The company has also updated its Android app to include a new feature called "Quick Settings," which allows users to quickly access the most important settings for their device. Users can also now access their phone's camera, microphone, and GPS from the Quick Settings menu.The company also added a number of new features to the Android operating systems, including a "Google Now" voice search feature, a feature that allows you to search for information on your phone, as well as a search bar that lets you search by name, location, or even your favorite words. Google Now also includes a list of popular apps that you can use to find information, such as Google Maps, Google Calendar, Gmail, YouTube, Twitter, Facebook, Instagram, Pinterest, Flipboard, Pandora, Spotify, Skype, Viber
# Reference: Here? Read it.
#
# Prompt 20: We'll be loaded with 2,000 pounds of bombs and 1,500 pounds of fuel
# Generated: We'll be loaded with 2,000 pounds of bombs and 1,500 pounds of fuel, and we'll have a lot of people on board," he said.
#
# The plane will be equipped with a parachute system that will allow it to land safely on the ground. The plane's crew will also be able to use the parachute to get out of the plane.
# Reference: We'll be loaded with 2,000 pounds of bombs and 1,500 pounds of fuel.  I got another Chinese phrase for Doolittle. "Mug wump rickshaw mushu pork."  It means "Who the fuck thought up this shit?" They'll turn the ship into the wind before we launch.  That'll help. It's shorter than our practice runway.
#
# BLEU score: 8.411395690393723
